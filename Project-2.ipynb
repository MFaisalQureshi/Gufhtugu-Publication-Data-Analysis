# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
table1=pd.read_csv(r'C:\Users\faisa\Desktop\GP Orders - 2.csv',encoding='UTF-8')
table1
# Out:
#        Order Number Order Status  \
# 0             70978    Completed
# 1             70962    Completed
# 2             70960    Completed
# 3             70959    Completed
# 4             70958    Completed
# ...             ...          ...
# 19182           311    Completed
# 19183           310     Returned
# 19184           309    Completed
# 19185           308    Completed
# 19186           307    Completed
#
#                                                Book Name       Order Date  \
# 0                             Column Nigari Kese Sekhain  1/20/2021 17:43
# 1                                 ??????? ?? ???? ??????  1/20/2021 13:37
# 2                    Justju ka safar-1/Waqfa e Pareshani  1/20/2021 10:48
# 3                                            R ka Taaruf  1/20/2021 10:32
# 4                                 ??????? ?? ???? ??????  1/20/2021 10:29
# ...                                                  ...              ...
# 19182  Bit Coin Block Chain aur Crypto Currency ?? ??...  10/3/2019 16:44
# 19183                               Kaggle for Begginers  10/3/2019 16:42
# 19184  Kaggle for Begginers/Bitcoin Blockchain aur Cr...  10/3/2019 16:09
# 19185                               Kaggle for Begginers  10/3/2019 15:54
# 19186  Bitcoin Blockchain aur Crypto Currency - FREE ...  10/3/2019 15:03
#
#       City (Billing)
# 0               Swat
# 1            Karachi
# 2            Karachi
# 3            Karachi
# 4            Karachi
# ...              ...
# 19182       Karachi
# 19183     Rawalpindi
# 19184      Hyderabad
# 19185     Rawalpindi
# 19186     faisalabad
#
# [19187 rows x 5 columns]

# %%
table2=pd.read_csv(r'C:\Users\faisa\Desktop\GP Orders - 4.csv',encoding='UTF-8')
table2
# Out:
#        Order Number Order Status  \
# 0             70978    Completed
# 1             70962    Completed
# 2             70960    Completed
# 3             70959    Completed
# 4             70958    Completed
# ...             ...          ...
# 19182           311    Completed
# 19183           310     Returned
# 19184           309    Completed
# 19185           308    Completed
# 19186           307    Completed
#
#                                                Book Name       Order Date  \
# 0                             Column Nigari Kese Sekhain  1/20/2021 17:43
# 1                                 انٹرنیٹ سے پیسہ کمائیں  1/20/2021 13:37
# 2                    Justju ka safar-1/Waqfa e Pareshani  1/20/2021 10:48
# 3                                            R ka Taaruf  1/20/2021 10:32
# 4                                 انٹرنیٹ سے پیسہ کمائیں  1/20/2021 10:29
# ...                                                  ...              ...
# 19182  Bit Coin Block Chain aur Crypto Currency بٹ کو...  10/3/2019 16:44
# 19183                               Kaggle for Begginers  10/3/2019 16:42
# 19184  Kaggle for Begginers/Bitcoin Blockchain aur Cr...  10/3/2019 16:09
# 19185                               Kaggle for Begginers  10/3/2019 15:54
# 19186  Bitcoin Blockchain aur Crypto Currency - FREE ...  10/3/2019 15:03
#
#       City (Billing)
# 0               Swat
# 1            Karachi
# 2            Karachi
# 3            Karachi
# 4            Karachi
# ...              ...
# 19182       Karachi
# 19183     Rawalpindi
# 19184      Hyderabad
# 19185     Rawalpindi
# 19186     faisalabad
#
# [19187 rows x 5 columns]

# %%
table3=pd.read_csv(r'C:\Users\faisa\Desktop\GP Orders - 5.csv',encoding='UTF-8')
table3
# Out:
#        Order Number Order Status  \
# 0               307    Completed
# 1               308    Completed
# 2               309    Completed
# 3               310    Cancelled
# 4               311    Completed
# ...             ...          ...
# 19234         71332    Completed
# 19235         71394    Completed
# 19236         71418    Completed
# 19237         71419    Completed
# 19238         71420    Completed
#
#                                                Book Name Order Date & Time  \
# 0      Bitcoin Blockchain aur Crypto Currency - FREE ...   10/3/2019 15:03
# 1                                   Kaggle for Begginers   10/3/2019 15:54
# 2      Kaggle for Begginers/Bitcoin Blockchain aur Cr...   10/3/2019 16:09
# 3                                   Kaggle for Begginers   10/3/2019 16:42
# 4      Bit Coin Block Chain aur Crypto Currency بٹ کو...   10/3/2019 16:44
# ...                                                  ...               ...
# 19234                            Linux - An Introduction   1/25/2021 12:46
# 19235  R ka Taaruf/ڈیٹا سائنس/Python Programming/Kagg...   1/25/2021 14:06
# 19236  Blockchain, Cryptocurrency And Bitcoin/Column ...   1/25/2021 16:37
# 19237  مشین لرننگ/ڈیٹا سائنس/Artificial Intelligence/...   1/25/2021 18:01
# 19238  Linux - An Introduction/Python Programming/Kag...   1/25/2021 20:47
#
#                           City          Payment Method  Total items  \
# 0                   faisalabad                     NaN            2
# 1                   Rawalpindi  Cash on Delivery (COD)            1
# 2                    Hyderabad  Cash on Delivery (COD)            2
# 3                   Rawalpindi  Cash on Delivery (COD)            1
# 4                     Karachi   Cash on Delivery (COD)            1
# ...                        ...                     ...          ...
# 19234                   Lahore        Cash on delivery            1
# 19235                   Lahore        Cash on delivery            4
# 19236                  Larkana        Cash on delivery            2
# 19237  Mailsi, district Vehari        Cash on delivery           10
# 19238                   Lahore        Cash on delivery            7
#
#        Total weight (grams)
# 0                     200.0
# 1                     200.0
# 2                     200.0
# 3                     200.0
# 4                     200.0
# ...                     ...
# 19234                 200.0
# 19235                 200.0
# 19236                 500.0
# 19237                 400.0
# 19238                 400.0
#
# [19239 rows x 8 columns]

# %%
tables=table1.append(table2,ignore_index=True)
tables
# Out:
#        Order Number Order Status  \
# 0             70978    Completed
# 1             70962    Completed
# 2             70960    Completed
# 3             70959    Completed
# 4             70958    Completed
# ...             ...          ...
# 38369           311    Completed
# 38370           310     Returned
# 38371           309    Completed
# 38372           308    Completed
# 38373           307    Completed
#
#                                                Book Name       Order Date  \
# 0                             Column Nigari Kese Sekhain  1/20/2021 17:43
# 1                                 ??????? ?? ???? ??????  1/20/2021 13:37
# 2                    Justju ka safar-1/Waqfa e Pareshani  1/20/2021 10:48
# 3                                            R ka Taaruf  1/20/2021 10:32
# 4                                 ??????? ?? ???? ??????  1/20/2021 10:29
# ...                                                  ...              ...
# 38369  Bit Coin Block Chain aur Crypto Currency بٹ کو...  10/3/2019 16:44
# 38370                               Kaggle for Begginers  10/3/2019 16:42
# 38371  Kaggle for Begginers/Bitcoin Blockchain aur Cr...  10/3/2019 16:09
# 38372                               Kaggle for Begginers  10/3/2019 15:54
# 38373  Bitcoin Blockchain aur Crypto Currency - FREE ...  10/3/2019 15:03
#
#       City (Billing)
# 0               Swat
# 1            Karachi
# 2            Karachi
# 3            Karachi
# 4            Karachi
# ...              ...
# 38369       Karachi
# 38370     Rawalpindi
# 38371      Hyderabad
# 38372     Rawalpindi
# 38373     faisalabad
#
# [38374 rows x 5 columns]

# %%
tables.head(10)
# Out:
#    Order Number Order Status                                 Book Name  \
# 0         70978    Completed                Column Nigari Kese Sekhain
# 1         70962    Completed                    ??????? ?? ???? ??????
# 2         70960    Completed       Justju ka safar-1/Waqfa e Pareshani
# 3         70959    Completed                               R ka Taaruf
# 4         70958    Completed                    ??????? ?? ???? ??????
# 5         70957    Completed    Blockchain, Cryptocurrency And Bitcoin
# 6         70956    Completed                          Firdaus E Bareen
# 7         70955    Completed                      Kaggle for Begginers
# 8         70954    Completed  ???? ?????/???? ?????/QATRA QATRA QULZAM
# 9         70953    Completed                        ????? ??????? ????
#
#         Order Date                 City (Billing)
# 0  1/20/2021 17:43                           Swat
# 1  1/20/2021 13:37                        Karachi
# 2  1/20/2021 10:48                        Karachi
# 3  1/20/2021 10:32                        Karachi
# 4  1/20/2021 10:29                        Karachi
# 5  1/20/2021 10:24                        Karachi
# 6   1/20/2021 9:28  Wah Cantt, Taxila, Rawalpindi
# 7   1/20/2021 8:05                     Bahawalpur
# 8   1/20/2021 5:48                         Lahore
# 9   1/20/2021 4:20                          Matli

# %%
tables.isna().sum()
# Out:
# Order Number      0
# Order Status      0
# Book Name         4
# Order Date        0
# City (Billing)    2
# dtype: int64

# %%
tables.rename(columns={'City (Billing)':'City'},inplace=True)

# %%
tables
# Out:
#        Order Number Order Status  \
# 0             70978    Completed
# 1             70962    Completed
# 2             70960    Completed
# 3             70959    Completed
# 4             70958    Completed
# ...             ...          ...
# 38369           311    Completed
# 38370           310     Returned
# 38371           309    Completed
# 38372           308    Completed
# 38373           307    Completed
#
#                                                Book Name       Order Date  \
# 0                             Column Nigari Kese Sekhain  1/20/2021 17:43
# 1                                 ??????? ?? ???? ??????  1/20/2021 13:37
# 2                    Justju ka safar-1/Waqfa e Pareshani  1/20/2021 10:48
# 3                                            R ka Taaruf  1/20/2021 10:32
# 4                                 ??????? ?? ???? ??????  1/20/2021 10:29
# ...                                                  ...              ...
# 38369  Bit Coin Block Chain aur Crypto Currency بٹ کو...  10/3/2019 16:44
# 38370                               Kaggle for Begginers  10/3/2019 16:42
# 38371  Kaggle for Begginers/Bitcoin Blockchain aur Cr...  10/3/2019 16:09
# 38372                               Kaggle for Begginers  10/3/2019 15:54
# 38373  Bitcoin Blockchain aur Crypto Currency - FREE ...  10/3/2019 15:03
#
#              City
# 0            Swat
# 1         Karachi
# 2         Karachi
# 3         Karachi
# 4         Karachi
# ...           ...
# 38369    Karachi
# 38370  Rawalpindi
# 38371   Hyderabad
# 38372  Rawalpindi
# 38373  faisalabad
#
# [38374 rows x 5 columns]

# %%
tables1=tables.append(table3,ignore_index=True)
table_csv=tables1.to_csv('table.csv')
Table=pd.read_csv('table.csv')
Table
# Out:
#        Unnamed: 0  Order Number Order Status  \
# 0               0         70978    Completed
# 1               1         70962    Completed
# 2               2         70960    Completed
# 3               3         70959    Completed
# 4               4         70958    Completed
# ...           ...           ...          ...
# 57608       57608         71332    Completed
# 57609       57609         71394    Completed
# 57610       57610         71418    Completed
# 57611       57611         71419    Completed
# 57612       57612         71420    Completed
#
#                                                Book Name       Order Date  \
# 0                             Column Nigari Kese Sekhain  1/20/2021 17:43
# 1                                 ??????? ?? ???? ??????  1/20/2021 13:37
# 2                    Justju ka safar-1/Waqfa e Pareshani  1/20/2021 10:48
# 3                                            R ka Taaruf  1/20/2021 10:32
# 4                                 ??????? ?? ???? ??????  1/20/2021 10:29
# ...                                                  ...              ...
# 57608                            Linux - An Introduction              NaN
# 57609  R ka Taaruf/ڈیٹا سائنس/Python Programming/Kagg...              NaN
# 57610  Blockchain, Cryptocurrency And Bitcoin/Column ...              NaN
# 57611  مشین لرننگ/ڈیٹا سائنس/Artificial Intelligence/...              NaN
# 57612  Linux - An Introduction/Python Programming/Kag...              NaN
#
#                           City Order Date & Time    Payment Method  \
# 0                         Swat               NaN               NaN
# 1                      Karachi               NaN               NaN
# 2                      Karachi               NaN               NaN
# 3                      Karachi               NaN               NaN
# 4                      Karachi               NaN               NaN
# ...                        ...               ...               ...
# 57608                   Lahore   1/25/2021 12:46  Cash on delivery
# 57609                   Lahore   1/25/2021 14:06  Cash on delivery
# 57610                  Larkana   1/25/2021 16:37  Cash on delivery
# 57611  Mailsi, district Vehari   1/25/2021 18:01  Cash on delivery
# 57612                   Lahore   1/25/2021 20:47  Cash on delivery
#
#        Total items  Total weight (grams)
# 0              NaN                   NaN
# 1              NaN                   NaN
# 2              NaN                   NaN
# 3              NaN                   NaN
# 4              NaN                   NaN
# ...            ...                   ...
# 57608          1.0                 200.0
# 57609          4.0                 200.0
# 57610          2.0                 500.0
# 57611         10.0                 400.0
# 57612          7.0                 400.0
#
# [57613 rows x 10 columns]

# %%
Table['Book Name']=Table['Book Name'].str.split("/")
Table=Table.explode("Book Name",ignore_index=True)
Table['Book Name']=Table['Book Name'].str.split("- ")
Table=Table.explode("Book Name",ignore_index=True)
Table['Book Name']=Table['Book Name'].str.split("?")
Table=Table.explode("Book Name",ignore_index=True)
Table= Table.replace(to_replace=r"^\s*$", value=np.NAN, regex=True)
Table=Table.replace(to_replace=r"^[!(-. \d]*$", value=np.NAN, regex=True)
Table= Table.replace(to_replace=r"^Release Date$", value=np.NAN, regex=True)
Table=Table.dropna(subset=["Book Name"])
Table
# Out:
#         Unnamed: 0  Order Number Order Status  \
# 0                0         70978    Completed
# 21               2         70960    Completed
# 22               2         70960    Completed
# 23               3         70959    Completed
# 44               5         70957    Completed
# ...            ...           ...          ...
# 232686       57612         71420    Completed
# 232687       57612         71420    Completed
# 232688       57612         71420    Completed
# 232689       57612         71420    Completed
# 232690       57612         71420    Completed
#
#                                      Book Name       Order Date     City  \
# 0                   Column Nigari Kese Sekhain  1/20/2021 17:43     Swat
# 21                           Justju ka safar-1  1/20/2021 10:48  Karachi
# 22                           Waqfa e Pareshani  1/20/2021 10:48  Karachi
# 23                                 R ka Taaruf  1/20/2021 10:32  Karachi
# 44      Blockchain, Cryptocurrency And Bitcoin  1/20/2021 10:24  Karachi
# ...                                        ...              ...      ...
# 232686                    Kaggle for Begginers              NaN   Lahore
# 232687                 Artificial Intelligence              NaN   Lahore
# 232688                        ایک تھا الگورتھم              NaN   Lahore
# 232689                             R ka Taaruf              NaN   Lahore
# 232690                              مشین لرننگ              NaN   Lahore
#
#        Order Date & Time    Payment Method  Total items  Total weight (grams)
# 0                    NaN               NaN          NaN                   NaN
# 21                   NaN               NaN          NaN                   NaN
# 22                   NaN               NaN          NaN                   NaN
# 23                   NaN               NaN          NaN                   NaN
# 44                   NaN               NaN          NaN                   NaN
# ...                  ...               ...          ...                   ...
# 232686   1/25/2021 20:47  Cash on delivery          7.0                 400.0
# 232687   1/25/2021 20:47  Cash on delivery          7.0                 400.0
# 232688   1/25/2021 20:47  Cash on delivery          7.0                 400.0
# 232689   1/25/2021 20:47  Cash on delivery          7.0                 400.0
# 232690   1/25/2021 20:47  Cash on delivery          7.0                 400.0
#
# [97729 rows x 10 columns]

# %%
Table['City']=Table['City'].str.split("?")
Table=Table.explode('City',ignore_index=True)
Table=Table.replace(to_replace="^[? ]*$",value=np.NAN,regex=True)
changename={
    "karachi":"Karachi",
    "KARACHI":"Karachi",
    "lahore":"Lahore",
    "LAHORE":"Lahore",
    "Mailsi, district":"Vehari",
    "Clifton / Karachi":"Karachi",
    "tehsil Bhalwal District ":"Sargodha",
    " faisalabad":" Faisalabad",
    " جھنگ":"Jhang",
    " Wah Cantt, Taxila, Rawalpindi":"Rawalpindi",
    "Jauharabad , Distt Khushab":"Khushab",
    " Midel town lahore":"Lahore",
    "Gagoo Mandi tehsil Burewala district vehari":"Vehari",
    " Mustufa Town, Wahdat Road, Lahore.":"Lahore",
    " Rahim Yar Khan":"Rahim yar Khan",
    "islamabad":"Islamabad",
    "Agrics Town, Raiwand Road Lahore":"Lahore",
    "Kallar Syedan dist Rawalpindi":"Rawalpindi",
    " Lahore, Pakistan":" Lahore",
    "Ahmed pur sial Jhang":"Jhang",
    " Lyari, Karachi":"Karachi",
    " Rawal pindi":" Rawalpindi",
    " Academy Town, peshawar":"Peshawar",
    " Peshawar Gulbahar no.1":" Peshawar",
    "North Nazimabad Karachi":"Karachi",
    " Khurrianwla faisalabad":"Faisalabad",
    "Ali town adyala road rawalpindi.":"Rawalpindi",
    " North Karachi":"Karachi",
    "Khi":"Karachi",
    "لاہور":"Lahore",
    " Madina town, Faisalabad":"Faisalabad",
    "Ahmed pur sial Jhang":"Jhang",
    "multan":"Multan",
    "مانسہرہ":"Mansehra",
    " mansehra":"Mansehra",
    "Rawalpindi cant":"Rawalpindi"
    
}
Table['City']=Table['City'].replace(changename)

# %%
Top_10_books=Table.groupby("Book Name")["Order Number"].agg(["count"]).reset_index().sort_values(by="count",ascending=False).head(10)
Top_10_books
# Out:
#                                    Book Name  count
# 1161                      Python Programming   8521
# 1691                  انٹرنیٹ سے پیسہ کمائیں   7577
# 207                  Artificial Intelligence   6643
# 337   Blockchain, Cryptocurrency And Bitcoin   6054
# 1155                      Product Management   4965
# 813                        Justju ka safar-1   4915
# 1371                       Sukkur To Florida   2153
# 1007                             Molo Masali   2137
# 1820                              ڈیٹا سائنس   2020
# 1                                      (C++)   1982

# %%
plt.figure(figsize=(10,5))
graph=sns.barplot(x='Book Name',y='count',data=Top_10_books)
graph.set_title('Top 10 Selling Books')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\faisa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1746 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\faisa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\faisa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1746 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\faisa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1729 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
Topleastbook=Table.groupby('Book Name')['Order Number'].agg(['count']).reset_index().sort_values(by='count',ascending=False).tail(10)
print(Topleastbook)
# Out:
#                                         Book Name  count
# 1733                                  توبۃ النصوح      2
# 1734  جدید تقریریں اور منتخب ایوارڈ یافتہ تقریریں      2
# 1736                          جنت کے پتے یکجا بڑی      2
# 1737               جنسی مسائل اپنا علاج خود کیجئے      2
# 1741                         حاتم طائی کی کہانیاں      2
# 0                                  'Arry and Bert      2
# 673                                 Hazir Ghayab       1
# 938                                  Madaam Curie      1
# 783                                        JAVA        1
# 1186                  RIYAD AL-SALIHEEN (ARABIC)       1

# %%
plt.figure(figsize=(15,5))
graph=sns.barplot(x='Book Name',y='count',data=Topleastbook)
graph.set_title('Top 10 Least Book Sold Out')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\faisa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1731 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\faisa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\faisa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1746 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\faisa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1731 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\faisa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1729 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\faisa\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1746 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
Top_10_city=Table.groupby("City")["Order Number"].agg(["count"]).reset_index().sort_values(by="count",ascending=False).head(10)
Top_10_city
# Out:
#             City  count
# 1480     Karachi  15596
# 1784      Lahore  12052
# 1235   Islamabad   6940
# 2723  Rawalpindi   3431
# 814   Faisalabad   2489
# 2200      Multan   2227
# 2505    Peshawar   2045
# 1001  Gujranwala   1385
# 1200   Hyderabad   1167
# 3070     Sialkot   1092

# %%
plt.figure(figsize=(12,5))
graph=sns.barplot(x="City",y="count",data=Top_10_cities)
graph.set_title("Top 10 Cities In whcih Book Sold Out")
plt.xticks(rotation=90)
plt.show()

# %%
Change={"Canceled":"Cancelled"}
Table["Order Status"]=Table["Order Status"].replace(Change)
orderstatus=Table.groupby('Order Status')['Order Number'].agg(['count']).reset_index()
print(orderstatus)
# Out:
#   Order Status  count
# 0    Cancelled    391
# 1    Completed  98038
# 2     Returned   7022

# %%
graph=sns.barplot(x="Order Status",y="count",data=orderstatus)
graph.set_title("Order Status")
plt.show()

# %%
Changepay={"Cash on Delivery (COD)":"Cash on delivery"}
Table['Payment Method']=Table['Payment Method'].replace(Changepay)
paymethod=Table.groupby('Payment Method')['Order Number'].agg(['count']).reset_index()
print(paymethod)
# Out:
#      Payment Method  count
# 0      BankTransfer   1543
# 1  Cash on delivery  31546
# 2         EasyPaisa   1356
# 3          JazzCash    989

# %%
plt.figure(figsize=(10,5))
graph=sns.barplot(x="Payment Method",y="count",data=paymethod)
graph.set_title("Payment Method")
plt.show()

# %%
Table['Order Date']=pd.to_datetime(Table['Order Date'])
Table['Year']=Table['Order Date'].dt.year
Orderreceive=Table.groupby("Year")['Order Number'].agg(['count']).reset_index().sort_values(by='count',ascending=False)
print(Orderreceive)
# Out:
#      Year  count
# 1  2020.0  54007
# 2  2021.0  15060
# 0  2019.0    930

# %%
graph=sns.barplot(x='Year',y='count',data=Orderreceive,hue="Year")
graph.set_title("Most Orders in a Year")
plt.show()

# %%
Completeorder=Table[Table['Order Status']=='Completed']
Completedorder=Completeorder.groupby('City')['Order Number'].agg(['count']).reset_index().sort_values(by='count',ascending=False).head(10)
print(Completedorder)
# Out:
#             City  count
# 1383     Karachi  14560
# 1665      Lahore  11469
# 1147   Islamabad   6193
# 2541  Rawalpindi   3277
# 760   Faisalabad   2383
# 2050      Multan   2112
# 2337    Peshawar   1856
# 930   Gujranwala   1313
# 2859     Sialkot   1065
# 1115   Hyderabad   1046

# %%
plt.figure(figsize=(15,5))
graph=sns.barplot(x='City',y='count',data=Completedorder)
graph.set_title('Top 10 City Which Completed Order')
plt.show()

# %%
cancelorder=Table[Table['Order Status']=='Cancelled']
CancelOrder=Table.groupby('City')['Order Number'].agg(['count']).reset_index().sort_values(by='count',ascending=False).head(10)
print(CancelOrder)
# Out:
#             City  count
# 1480     Karachi  15596
# 1784      Lahore  12052
# 1235   Islamabad   6940
# 2723  Rawalpindi   3431
# 814   Faisalabad   2489
# 2200      Multan   2227
# 2505    Peshawar   2045
# 1001  Gujranwala   1385
# 1200   Hyderabad   1167
# 3070     Sialkot   1092

# %%
plt.figure(figsize=(15,5))
graph=sns.barplot(x='City',y='count',data=CancelOrder)
graph.set_title("Top 10 Cities Which Cancelled Order")
plt.show()

# %%
returnorder=Table[Table['Order Status']=='Returned']
ReturnOrder=returnorder.groupby('City')['Order Number'].agg(['count']).reset_index().sort_values(by='count',ascending=False).head(10)
print(ReturnOrder)
# Out:
#                          City  count
# 206                   Karachi    975
# 174                 Islamabad    738
# 245                    Lahore    549
# 377                Rawalpindi    243
# 225                   Kharain    227
# 350                  Peshawar    179
# 170                 Hyderabad    121
# 407  Seem Afzalpur mirpur ajk    116
# 309                    Multan    106
# 367                    Quetta     87

# %%
plt.figure(figsize=(18,5))
graph=sns.barplot(x='City',y='count',data=ReturnOrder)
graph.set_title('Top 10 Cities Which Returned Order ')
plt.show()
